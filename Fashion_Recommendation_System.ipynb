# %%
from zipfile import ZipFile
import os

zip_file_path = 'women-fashion.zip'
extraction_directory = 'women_fashion/'

if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

# %%
with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)

# %%
extracted_files = os.listdir(extraction_directory)
print(extracted_files[:10])
# Out:
# ['women fashion', '__MACOSX']

# %%
# correcting the path to include the 'women fashion' directory and listing its contents
extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')

# %%
# list the files in the updated directory
extracted_files_updated = os.listdir(extraction_directory_updated)
extracted_files_updated[0:], len(extracted_files_updated)
# Out:
# (['.DS_Store',
#   'anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg',
#   'Anarkali suit with a modern twist.jpg',
#   'Anarkali suit with fitted bodice with a high neckline.jpg',
#   'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg',
#   'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg',
#   'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg',
#   'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg',
#   'beige top adorned with black dots and a green skirt.jpg',
#   'black and white gingham checkered A-line dress with a flared skirt.jpg',
#   'black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg',
#   'black dress with lace detailing.jpg',
#   'black dress with sparkling details.jpg',
#   'black floral saree.jpg',
#   'black jumpsuit with a diagonal stripe of glittering material running across the body.jpg',
#   'black lace bustier top paired with high-waisted black trousers.jpg',
#   'black off-shoulder dress with belt.jpg',
#   'black top with spaghetti straps and a black skirt adorned with a fringe detail at the hem.jpg',
#   'black top, white trousers.jpg',
#   'black, sequined dress with thin shoulder straps.jpg',
#   'blue dress with a floral pattern.jpg',
#   'bright red kurta with an intricate patterned design.jpg',
#   'bright red, form-fitting, strapless dress with a high slit on one side revealing part of the leg.jpg',
#   'bright red, sequined dress with thin shoulder straps.jpg',
#   'burgundy off-the-shoulder dress with an asymmetrical hemline.jpg',
#   'burnt orange long-sleeve top, a plaid skirt with brown tones, and a matching burnt orange beret.jpeg',
#   'chic and elegant outfit consisting of a pair of high-waisted wide-leg trousers paired with a long-sleeve sheer lace top.jpg',
#   'classic black slip dress with a midi length.jpg',
#   'colorful saree.jpg',
#   'cream-colored, long, open-front coat with wide lapels.jpg',
#   'dark blue, knee-length dress with thin straps.jpg',
#   'dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg',
#   'deep burgundy, silky dress with long sleeves and a wrap-style front.jpg',
#   'dress with a classic black and white houndstooth pattern.jpg',
#   'fitted black dress that reaches down to mid-calf.jpg',
#   'fitted dress with a classic black and white houndstooth pattern.webp',
#   'fitted, cream-colored dress with long sheer sleeves.jpg',
#   'fitted, off-the-shoulder white dress with horizontal ribbed texture.jpg',
#   'fitted, ruched dress with a sweetheart neckline and long mesh sleeves.jpg',
#   'fitted, short, yellow dress with short sleeves.jpeg',
#   'floral dress with long sleeves.jpeg',
#   'flowing green off-shoulder dress.jpg',
#   'fluffy, possibly faux fur or eyelash knit sweater with a cropped cut top.jpg',
#   'form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg',
#   'glamorous two-piece outfit featuring a sequined design.jpeg',
#   'green dress with a floral pattern, paired with matching green trousers.jpg',
#   'high-waisted white trousers paired with a structured, corset-style bodice featuring mesh.jpg',
#   'l-htdrss7133-honky-tonky-original-imagszfhfghhs2rp.jpeg',
#   'ladies-party-wear-cotton-short-dress-full.jpg',
#   'Latest-Party-Wear-One-Piece-Gown-For-Women.webp',
#   'light blue, sequined dress with a V-neckline, long sleeves.jpg',
#   'light brown sleeveless double-breasted blazer paired with matching straight-leg trousers.jpg',
#   'light green, short dress with lace detailing around the waist and the edges of the sleeves and hem.jpg',
#   'light peach, knee-length dress with off-the-shoulder sleeves.webp',
#   'long, elegant blue dress with an off-the-shoulder design with sheer sleeves.jpg',
#   'long, elegant, teal dress with a high slit on one side.jpg',
#   'long, flowing dress with a full skirt.jpg',
#   'long, flowing, pink dress with a sparkly texture.jpg',
#   'long, intricately designed dress with full sleeves.jpg',
#   'metallic-looking jacket with intricate designs and fringes hanging from the sleeves.jpg',
#   'mustard yellow fitted dress with white off-the-shoulder sleeves.webp',
#   'off-the-shoulder black ball gown.jpg',
#   'one-shoulder, black, sequined dress with fringe detailing at the hem.jpg',
#   'one-shoulder, fitted dress that features sequin embellishments and sheer panels.jpg',
#   'pink, knee-length dress that sparkles.jpg',
#   'red dress adorned with an intricate white pattern.jpg',
#   'red dress with a pattern of small white flowers.jpg',
#   'red velvet sheath midi dress.jpg',
#   'royal blue off-shoulder dress.jpg',
#   'salwar kameez in a vibrant red color with detailed embroidery.jpg',
#   'shiny purple sequined dress with a one-shoulder design.jpg',
#   'shiny, silver, wrap-style dress with long sleeves.jpg',
#   'short, blue floral dress with long puffed sleeves.jpg',
#   'short, white, sleeveless dress with thin straps.jpg',
#   'sleeveless dress adorned with pink sequins.jpg',
#   'sleeveless dress with a high neckline.jpeg',
#   'Sleeveless-Ruched-Tight-Fashion-Sexy-Bodycon-Party-Women-Club-Dresses.webp',
#   'solid dark blue top and a floral pattern on the bottom.jpg',
#   'sophisticated black dress with an asymmetrical design with one sleeve and a strapless neckline on the opposite side.jpg',
#   'sparkling black dress.jpg',
#   'sparkling blue dress.jpeg',
#   'sparkling white dress with long sleeves.jpg',
#   'sparkling, fitted dress 2.jpeg',
#   'sparkling, fitted dress with long sleeves.jpg',
#   'sparkling, fitted dress.jpeg',
#   'sparkling, sequined dress.jpg',
#   'strapless red midi dress with a mermaid silhouette.jpg',
#   'strapless, sequined dress that sparkles with multiple colors.jpg',
#   'tight-fitting, off-the-shoulder white dress 2.jpg',
#   'tight-fitting, off-the-shoulder white dress.webp',
#   'vibrant blue and a neutral tone adorned with colorful floral patterns.jpg',
#   'well-fitted beige suit.jpg',
#   'white dress adorned with colorful floral patterns.jpg',
#   'white knee-length dress with a fitted design and long sleeves.webp',
#   'white, intricately detailed top and a flowing dark blue skirt.jpg',
#   'Women-off-the-shoulder-sexy-embroidery-fashion-party-dress-1.png',
#   'yellow, intricately designed Anarkali suit.jpeg'],
#  97)

# %%
pip install PIL
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
from PIL import Image
import matplotlib.pyplot as plt
# function to load and display an image
def display_image(file_path):
    image = Image.open(file_path)
    plt.imshow(image)
    plt.axis('off')
    plt.show()


# display the first image to understand its characteristics
first_image_path = os.path.join(extraction_directory_updated, extracted_files_updated[0])
display_image(first_image_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from PIL import Image
#       2 import matplotlib.pyplot as plt
#       3 # function to load and display an image
#
# ModuleNotFoundError: No module named 'PIL'

# %%
import glob

# directory path containing your images
image_directory = 'women_fashion/women fashion'

image_paths_list = [file for file in glob.glob(os.path.join(image_directory, '*.*')) if file.endswith(('.jpg', '.png', '.jpeg', 'webp'))]

# print the list of image file paths
print(image_paths_list)
# Out:
# ['women_fashion/women fashion/royal blue off-shoulder dress.jpg', 'women_fashion/women fashion/dress with a classic black and white houndstooth pattern.jpg', 'women_fashion/women fashion/black off-shoulder dress with belt.jpg', 'women_fashion/women fashion/Latest-Party-Wear-One-Piece-Gown-For-Women.webp', 'women_fashion/women fashion/beige top adorned with black dots and a green skirt.jpg', 'women_fashion/women fashion/anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'women_fashion/women fashion/cream-colored, long, open-front coat with wide lapels.jpg', 'women_fashion/women fashion/flowing green off-shoulder dress.jpg', 'women_fashion/women fashion/fitted, short, yellow dress with short sleeves.jpeg', 'women_fashion/women fashion/fitted, cream-colored dress with long sheer sleeves.jpg', 'women_fashion/women fashion/sparkling, sequined dress.jpg', 'women_fashion/women fashion/vibrant blue and a neutral tone adorned with colorful floral patterns.jpg', 'women_fashion/women fashion/fitted black dress that reaches down to mid-calf.jpg', 'women_fashion/women fashion/black lace bustier top paired with high-waisted black trousers.jpg', 'women_fashion/women fashion/fitted dress with a classic black and white houndstooth pattern.webp', 'women_fashion/women fashion/floral dress with long sleeves.jpeg', 'women_fashion/women fashion/sparkling black dress.jpg', 'women_fashion/women fashion/black dress with lace detailing.jpg', 'women_fashion/women fashion/bright red, sequined dress with thin shoulder straps.jpg', 'women_fashion/women fashion/long, elegant blue dress with an off-the-shoulder design with sheer sleeves.jpg', 'women_fashion/women fashion/form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg', 'women_fashion/women fashion/tight-fitting, off-the-shoulder white dress 2.jpg', 'women_fashion/women fashion/black and white gingham checkered A-line dress with a flared skirt.jpg', 'women_fashion/women fashion/light brown sleeveless double-breasted blazer paired with matching straight-leg trousers.jpg', 'women_fashion/women fashion/high-waisted white trousers paired with a structured, corset-style bodice featuring mesh.jpg', 'women_fashion/women fashion/one-shoulder, fitted dress that features sequin embellishments and sheer panels.jpg', 'women_fashion/women fashion/white knee-length dress with a fitted design and long sleeves.webp', 'women_fashion/women fashion/white dress adorned with colorful floral patterns.jpg', 'women_fashion/women fashion/well-fitted beige suit.jpg', 'women_fashion/women fashion/long, elegant, teal dress with a high slit on one side.jpg', 'women_fashion/women fashion/bright red kurta with an intricate patterned
1 MB/s eta 0:00:03
#    ------- -------------------------------- 2.8/15.5 MB 5.3 MB/s eta 0:00:03
#    -------- ------------------------------- 3.2/15.5 MB 5.6 MB/s eta 0:00:03
#    -------- ------------------------------- 3.5/15.5 MB 5.5 MB/s eta 0:00:03
#    --------- ------------------------------ 3.8/15.5 MB 5.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.9/15.5 MB 5.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.9/15.5 MB 5.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.3/15.5 MB 5.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.6/15.5 MB 5.3 MB/s eta 0:00:03
#    ------------ --------------------------- 5.0/15.5 MB 5.5 MB/s eta 0:00:02
#    ------------- -------------------------- 5.3/15.5 MB 5.6 MB/s eta 0:00:02
#    -------------- ------------------------- 5.7/15.5 MB 5.7 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.5 MB 5.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.4/15.5 MB 5.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.8/15.5 MB 5.9 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.5 MB 6.1 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.5 MB 6.1 MB/s eta 0:00:02
#    ------------------ --------------------- 7.2/15.5 MB 5.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.7/15.5 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 7.8/15.5 MB 5.8 MB/s eta 0:00:02
#    -------------------- ------------------- 7.9/15.5 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 7.9/15.5 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.5 MB 5.4 MB/s eta 0:00:02
#    --------------------- ------------------ 8.5/15.5 MB 5.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.8/15.5 MB 5.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.0/15.5 MB 5.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.0/15.5 MB 5.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.0/15.5 MB 5.5 MB/s eta 0:00:02
#    ------------------------ --------------- 9.3/15.5 MB 5.2 MB/s eta 0:00:02
#    ------------------------ --------------- 9.5/15.5 MB 5.3 MB/s eta 0:00:02
#    ------------------------ --------------- 9.5/15.5 MB 5.3 MB/s eta 0:00:02
#    ------------------------ --------------- 9.6/15.5 MB 5.0 MB/s eta 0:00:02
#    ------------------------- -------------- 9.8/15.5 MB 5.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.0/15.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.5 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.3/15.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.6/15.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------ --------- 11.9/15.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.5 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.3/15.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.3/15.5 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.5 MB 5.0 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 4.3 MB/s eta 0:00:00
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/413.4 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/413.4 kB ? eta -:--:--
#    ------------------------ --------------- 256.0/413.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  409.6/413.4 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 413.4/413.4 kB 2.0 MB/s eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Downloading setuptools-69.2.0-py3-none-any.whl (821 kB)
#    ---------------------------------------- 0.0/821.5 kB ? eta -:--:--
#    - -------------------------------------- 30.7/821.5 kB ? eta -:--:--
#    ----- ---------------------------------- 112.6/821.5 kB 1.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 235.5/821.5 kB 2.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 593.9/821.5 kB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 655.4/821.5 kB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 655.4/821.5 kB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 655.4/821.5 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  819.2/821.5 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 821.5/821.5 kB 2.1 MB/s eta 0:00:00
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Downloading wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 1.9 MB/s eta 0:00:00
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    ---------------------------------------- 105.4/105.4 kB 6.3 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.7 kB ? eta -:--:--
#    ---------------------------------------- 226.7/226.7 kB 7.0 MB/s eta 0:00:00
# Downloading wheel-0.43.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.8 kB ? eta -:--:--
#    ---------------------------------------- 65.8/65.8 kB 1.8 MB/s eta 0:00:00
# Using cached namex-0.0.7-py3-none-any.whl (5.8 kB)
# Downloading optree-0.10.0-cp312-cp312-win_amd64.whl (220 kB)
#    ---------------------------------------- 0.0/220.8 kB ? eta -:--:--
#    ----------------------------------- ---- 194.6/220.8 kB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 215.0/220.8 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 220.8/220.8 kB 2.3 MB/s eta 0:00:00
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorboard-data-server, setuptools, protobuf, numpy, mdurl, MarkupSafe, markdown, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, absl-py, werkzeug, requests, optree, opt-einsum, ml-dtypes, markdown-it-py, h5py, astunparse, tensorboard, rich, keras, tensorflow-intel, tensorflow
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 certifi-2024.2.2 charset-normalizer-3.3.2 flatbuffers-24.3.7 gast-0.5.4 google-pasta-0.2.0 grpcio-1.62.1 h5py-3.10.0 idna-3.6 keras-3.1.1 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.3.2 namex-0.0.7 numpy-1.26.4 opt-einsum-3.3.0 optree-0.10.0 protobuf-4.25.3 requests-2.31.0 rich-13.7.1 setuptools-69.2.0 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 termcolor-2.4.0 typing-extensions-4.10.0 urllib3-2.2.1 werkzeug-3.0.1 wheel-0.43.0 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.16.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: tensorflow-intel
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.output)

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded)

def extract_features(model, preprocessed_img):
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / np.linalg.norm(flattened_features)
    return normalized_features

all_features = []
all_image_names = []

for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
    all_image_names.append(os.path.basename(img_path))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from tensorflow.keras.preprocessing import image
#       2 from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
#       3 from tensorflow.keras.applications.vgg16 import preprocess_input
#
# File c:\Users\jeeva\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
#      28 # pylint: disable=g-bad-import-order,protected-access,g-import-not-at-top
# ---> 30 import distutils as _distutils
#      31 import importlib
#      32 import inspect as _inspect
#
# ModuleNotFoundError: No module named 'distutils'

# %%
from scipy.spatial.distance import cosine

def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=5):
    # pre-process the input image and extract features
    preprocessed_img = preprocess_image(input_image_path)
    input_features = extract_features(model, preprocessed_img)

    # calculate similarities and find the top N similar images
    similarities = [1 - cosine(input_features, other_feature) for other_feature in all_features]
    similar_indices = np.argsort(similarities)[-top_n:]

    # filter out the input image index from similar_indices
    similar_indices = [idx for idx in similar_indices if idx != all_image_names.index(input_image_path)]

    # display the input image
    plt.figure(figsize=(15, 10))
    plt.subplot(1, top_n + 1, 1)
    plt.imshow(Image.open(input_image_path))
    plt.title("Input Image")
    plt.axis('off')

    for i, idx in enumerate(similar_indices[:top_n], start=1):
      # image_path = os.path.join('women_fashion/women fashion', all_image_names[idx])
      image_path = all_image_names[idx]
      plt.subplot(1, top_n + 1, i + 1)
      plt.imshow(Image.open(image_path))
      plt.title(f"Recommendation {i}")
      plt.axis('off')
      plt.tight_layout()
      plt.show()
input_image_path = 'women_fashion/women fashion/fluffy, possibly faux fur or eyelash knit sweater with a cropped cut top.jpg'
# input_image_path = 'women_fashion/women fashion/dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg'
recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from scipy.spatial.distance import cosine
#       3 def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=5):
#       4     # pre-process the input image and extract features
#       5     preprocessed_img = preprocess_image(input_image_path)
#
# ModuleNotFoundError: No module named 'scipy'
